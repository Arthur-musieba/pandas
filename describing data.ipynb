# %%
import pandas as pd

# %%
df=pd.read_csv(r"vgsales.csv")

# %%
df.describe()
#this give all the stats about the data like mean, std, min and max values
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df
# Out:
#         Rank                                              Name    Year  \
# 0          1                                        Wii Sports  2006.0
# 1          2                                 Super Mario Bros.  1985.0
# 2          3                                    Mario Kart Wii  2008.0
# 3          4                                 Wii Sports Resort  2009.0
# 4          5                          Pokemon Red/Pokemon Blue  1996.0
# ...      ...                                               ...     ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5  2002.0
# 16594  16597                     Men in Black II: Alien Escape  2003.0
# 16595  16598  SCORE International Baja 1000: The Official Game  2008.0
# 16596  16599                                        Know How 2  2010.0
# 16597  16600                                  Spirits & Spells  2003.0
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
df.sort_values('Name', ascending=False)
# Out:
#         Rank                                     Name    Year  NA_Sales  \
# 9135    9137             ¡Shin Chan Flipa en colores!  2007.0      0.00
# 470      471               wwe Smackdown vs. Raw 2006     NaN      1.57
# 15523  15526             uDraw Studio: Instant Artist  2011.0      0.01
# 7835    7837             uDraw Studio: Instant Artist  2011.0      0.08
# 627      628                             uDraw Studio  2010.0      1.67
# ...      ...                                      ...     ...       ...
# 8304    8306            .hack//G.U. Vol.3//Redemption  2007.0      0.00
# 8602    8604  .hack//G.U. Vol.2//Reminisce (jp sales)  2006.0      0.00
# 7107    7109             .hack//G.U. Vol.2//Reminisce  2006.0      0.11
# 8357    8359               .hack//G.U. Vol.1//Rebirth  2006.0      0.00
# 4754    4756                              '98 Koshien  1998.0      0.15
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
df.sort_values('Name', ascending=True)
# Out:
#         Rank                                     Name    Year  NA_Sales  \
# 4754    4756                              '98 Koshien  1998.0      0.15
# 8357    8359               .hack//G.U. Vol.1//Rebirth  2006.0      0.00
# 7107    7109             .hack//G.U. Vol.2//Reminisce  2006.0      0.11
# 8602    8604  .hack//G.U. Vol.2//Reminisce (jp sales)  2006.0      0.00
# 8304    8306            .hack//G.U. Vol.3//Redemption  2007.0      0.00
# ...      ...                                      ...     ...       ...
# 627      628                             uDraw Studio  2010.0      1.67
# 7835    7837             uDraw Studio: Instant Artist  2011.0      0.08
# 15523  15526             uDraw Studio: Instant Artist  2011.0      0.01
# 470      471               wwe Smackdown vs. Raw 2006     NaN      1.57
# 9135    9137             ¡Shin Chan Flipa en colores!  2007.0      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...
